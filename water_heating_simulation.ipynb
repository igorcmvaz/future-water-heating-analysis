# %%
import sys, os, multiprocessing as mp
from typing import List, Literal, Dict, Tuple, Optional
import numpy as np
import pandas as pd
from pvlib.iotools import read_epw
from datetime import datetime
from concurrent.futures import ProcessPoolExecutor, ThreadPoolExecutor, as_completed

# === LOGS IMEDIATOS E EVITAR OVER-SUBSCRIPTION DE THREADS ===
try:
    sys.stdout.reconfigure(line_buffering=True)
except Exception:
    pass
os.environ.setdefault("OMP_NUM_THREADS", "1")
os.environ.setdefault("OPENBLAS_NUM_THREADS", "1")
os.environ.setdefault("NUMEXPR_MAX_THREADS", "1")

# -----------------------------
# Seleção de potência nominal
# -----------------------------
def select_nominal_power(
    required_kw: float,
    available_kw: List[float],
    method: Literal["ceil", "nearest"] = "ceil"
) -> float:
    available_kw = sorted(available_kw)
    if method == "ceil":
        for p in available_kw:
            if p >= required_kw:
                return p
        return available_kw[-1]
    else:  # nearest
        return min(available_kw, key=lambda x: abs(x - required_kw))

def _select_nominal_power_vectorized(
    req: np.ndarray,
    available: np.ndarray,
    method: str
) -> np.ndarray:
    available = np.sort(available)
    if method == "ceil":
        idx = np.searchsorted(available, req, side="left")
        idx = np.clip(idx, 0, len(available) - 1)
        return available[idx]
    else:  # nearest
        diffs = np.abs(req[:, None] - available[None, :])
        idx = diffs.argmin(axis=1)
        return available[idx]

# -----------------------------
# Carga da tabela do IPT e prep
# -----------------------------
def load_shower_reference(
    ipt_csv_path: str,
    ref_minutes_per_day: float = 8.0,
    min_flow_lpm_filter: float = 4.0
) -> Dict[str, object]:
    chuveiros = pd.read_csv(ipt_csv_path, encoding="latin-1", sep=";", decimal=",")
    chuveiros.columns = [c.strip() for c in chuveiros.columns]

    cols_esperadas = {
        "VAZÃO PARA CONSUMO MENSAL MÍNIMO (l/min)",
        "POTÊNCIA\n(W)",
        "CONSUMO MENSAL MÍNIMO\n(kWh/mês)",
        "CONSUMO MENSAL MÁXIMO\n(kWh/mês)",
        "ELEVAÇÃO DE\nTEMPERATURA PARA CONSUMO MENSAL MÁXIMO\n(ºC)",
    }
    if not cols_esperadas.issubset(set(chuveiros.columns)):
        raise ValueError("As colunas do CSV de chuveiros não estão corretamente nomeadas.")

    chuveiros = chuveiros[
        chuveiros["VAZÃO PARA CONSUMO MENSAL MÍNIMO (l/min)"] >= min_flow_lpm_filter
    ]

    potencias_W = sorted(list(chuveiros["POTÊNCIA\n(W)"].unique()))
    lista_potencias_kW = [w / 1000 for w in potencias_W]

    grupo = chuveiros[
        [
            "POTÊNCIA\n(W)",
            "CONSUMO MENSAL MÍNIMO\n(kWh/mês)",
            "CONSUMO MENSAL MÁXIMO\n(kWh/mês)",
            "ELEVAÇÃO DE\nTEMPERATURA PARA CONSUMO MENSAL MÁXIMO\n(ºC)",
        ]
    ].groupby("POTÊNCIA\n(W)").mean()

    grupo.index = grupo.index / 1000  # índice em kW
    grupo.index.name = "Potencia (kW)"

    grupo["CONSUMO MENSAL MÍNIMO\n(kWh/mês)"] /= (30.42 * ref_minutes_per_day)
    grupo["CONSUMO MENSAL MÁXIMO\n(kWh/mês)"] /= (30.42 * ref_minutes_per_day)

    grupo.columns = [
        "consumo_min_kWh_min",
        "consumo_max_kWh_min",
        "tmax_ref_C",
    ]
    return {
        "lista_potencias_kW": lista_potencias_kW,
        "curva_ref": grupo,
    }

# -----------------------------
# Núcleo vetorizado por EPW
# -----------------------------
def _process_one_epw_all_combos(
    file_path: str,
    hours: List[int],
    thresholds: List[int],
    bath_minutes: float,
    flow_lpm: float,
    efficiency: float,
    temp_usage_mode: str,
    temp_fixed_c: float,
    delta_min_c: float,
    curva_ref: pd.DataFrame,
    lista_potencias_kW: List[float],
    power_selection: str,
    north_northeast_states: set,
) -> Tuple[List[Dict[str, object]], Optional[str]]:
    try:
        # Parsing de nome do arquivo
        file = os.path.basename(file_path)
        parts = file.replace(".epw", "").split("_")
        state = parts[1] if len(parts) > 1 else "UF?"
        year_info = parts[-1]

        if "TMYx" in year_info:
            year = "2021"
            scenario = "Baseline"
        else:
            if len(parts) >= 3:
                scenario = parts[-2]
                year = parts[-1]
            else:
                scenario = "Desconhecido"
                year = "Desconhecido"

        # Temperatura de uso (alvo)
        if temp_usage_mode.upper() == "INI-R":
            temp_uso = 38.0 if state in north_northeast_states else 40.0
        elif temp_usage_mode.upper() == "FIXED":
            temp_uso = float(temp_fixed_c)
        else:
            raise ValueError("temp_usage_mode deve ser 'INI-R' ou 'FIXED'.")

        epw_data, meta = read_epw(file_path)
        city = meta.get("city", "Unknown")
        latitude = meta.get("latitude", None)
        longitude = meta.get("longitude", None)

        # Pré-processo
        idx = epw_data.index
        hours_col = idx.hour
        dates_col = idx.normalize()
        temps = epw_data["temp_air"].to_numpy()
        unique_days = pd.Index(np.unique(dates_col))

        available = np.array(sorted(lista_potencias_kW), dtype=float)

        rows_out: List[Dict[str, object]] = []

        # Para cada hora, pré-computar vetores por dia
        for h in hours:
            mask_h = (hours_col == h)
            if not np.any(mask_h):
                for tlim in thresholds:
                    rows_out.append({
                        "city": city, "state": state, "latitude": latitude, "longitude": longitude,
                        "year": year, "scenario": scenario, "bath_hours": str(h),
                        "bath_minutes": bath_minutes, "flow_lpm": flow_lpm, "efficiency": efficiency,
                        "temp_limit_c": tlim, "temp_usage_mode": temp_usage_mode,
                        "temp_usage_target_c": temp_uso, "power_selection": power_selection,
                        "consumo_anual_kWh": 0.0, "consumo_dia_min_kWh": 0.0, "consumo_dia_max_kWh": 0.0,
                        "required_kw_p95": 0.0, "nominal_kw_p95": 0.0, "required_kw_max": 0.0, "nominal_kw_max": 0.0,
                    })
                continue

            df_h = pd.DataFrame({"date": dates_col[mask_h], "temp": temps[mask_h]})
            per_day = df_h.groupby("date", sort=True)["temp"].mean()
            per_day = per_day.reindex(unique_days)
            temp_vec = per_day.to_numpy()

            # Potências requeridas e nominais (vetorizado)
            delta_T = (temp_uso - temp_vec)
            req_kw = (flow_lpm * 60.0 * delta_T) / (860.0 * efficiency)
            req_kw = np.nan_to_num(req_kw, nan=0.0)
            req_kw = np.maximum(req_kw, 0.0)

            nom_kw = _select_nominal_power_vectorized(req_kw, available, power_selection)

            ref_rows = curva_ref.reindex(pd.Series(nom_kw).values)
            cons_min = ref_rows["consumo_min_kWh_min"].to_numpy()
            cons_max = ref_rows["consumo_max_kWh_min"].to_numpy()
            t_max  = ref_rows["tmax_ref_C"].to_numpy()

            delta_for_cons = np.clip(delta_T, delta_min_c, None)
            delta_for_cons = np.minimum(delta_for_cons, t_max)
            use_linear = (t_max > delta_min_c)
            cons_per_min = np.where(
                use_linear,
                ((delta_for_cons - delta_min_c) * (cons_max - cons_min) / (t_max - delta_min_c)) + cons_min,
                cons_min
            )
            cons_per_min = np.nan_to_num(cons_per_min, nan=0.0)

            for tlim in thresholds:
                mask_banho = (temp_vec < tlim)
                daily_cons = np.where(mask_banho, bath_minutes * cons_per_min, 0.0)
                req_vec    = np.where(mask_banho, req_kw, 0.0)
                nom_vec    = np.where(mask_banho, nom_kw, 0.0)

                rows_out.append({
                    "city": city, "state": state, "latitude": latitude, "longitude": longitude,
                    "year": year, "scenario": scenario, "bath_hours": str(h),
                    "bath_minutes": bath_minutes, "flow_lpm": flow_lpm, "efficiency": efficiency,
                    "temp_limit_c": tlim, "temp_usage_mode": temp_usage_mode,
                    "temp_usage_target_c": temp_uso, "power_selection": power_selection,
                    "consumo_anual_kWh": round(float(daily_cons.sum()), 3),
                    "consumo_dia_min_kWh": round(float(daily_cons.min()) if daily_cons.size else 0.0, 4),
                    "consumo_dia_max_kWh": round(float(daily_cons.max()) if daily_cons.size else 0.0, 4),
                    "required_kw_p95": round(float(np.quantile(req_vec, 0.95)) if req_vec.size else 0.0, 3),
                    "nominal_kw_p95": round(float(np.quantile(nom_vec, 0.95)) if nom_vec.size else 0.0, 3),
                    "required_kw_max": round(float(req_vec.max()) if req_vec.size else 0.0, 3),
                    "nominal_kw_max": round(float(nom_vec.max()) if nom_vec.size else 0.0, 3),
                })

        return rows_out, None
    except Exception as e:
        return [], f"Erro ao processar {os.path.basename(file_path)}: {e}"

# -----------------------------
# Versão original (mantida)
# -----------------------------
def process_epw_files(
    epw_folder: str,
    output_csv_name: str = "consolidated",
    output_folder: str = "Output",
    bath_hours: List[int] = [18],
    bath_minutes: float = 8.0,
    flow_lpm: float = 4.0,
    efficiency: float = 0.95,
    temp_limit_c: float = 25.0,
    temp_usage_mode: Literal["INI-R", "FIXED"] = "INI-R",
    temp_fixed_c: float = 40.0,
    delta_min_c: float = 10.0,
    ipt_csv_path: str = "IPT_Chuveiros_Eletricos.csv",
    ref_minutes_per_day: float = 8.0,
    min_flow_lpm_filter: float = 4.0,
    power_selection: Literal["ceil", "nearest"] = "ceil",
) -> pd.DataFrame:
    north_northeast_states = {
        "AC","AP","AM","PA","RO","RR","TO",
        "AL","BA","CE","MA","PB","PE","PI","RN","SE"
    }

    ref = load_shower_reference(
        ipt_csv_path=ipt_csv_path,
        ref_minutes_per_day=ref_minutes_per_day,
        min_flow_lpm_filter=min_flow_lpm_filter,
    )
    lista_potencias_kW = ref["lista_potencias_kW"]
    curva_ref = ref["curva_ref"]

    epw_files = [f for f in os.listdir(epw_folder) if f.lower().endswith(".epw")]
    total_files = len(epw_files)

    os.makedirs(output_folder, exist_ok=True)

    output_rows = []
    start_ts = datetime.now().strftime("%Y%m%d_%H%M%S")
    print(f"Início: {start_ts} | EPWs: {total_files}")

    for idx, file in enumerate(epw_files, start=1):
        file_path = os.path.join(epw_folder, file)
        try:
            rows, err = _process_one_epw_all_combos(
                file_path=file_path,
                hours=bath_hours,
                thresholds=[int(temp_limit_c)],
                bath_minutes=bath_minutes,
                flow_lpm=flow_lpm,
                efficiency=efficiency,
                temp_usage_mode=temp_usage_mode,
                temp_fixed_c=temp_fixed_c,
                delta_min_c=delta_min_c,
                curva_ref=curva_ref,
                lista_potencias_kW=lista_potencias_kW,
                power_selection=power_selection,
                north_northeast_states=north_northeast_states,
            )
            if err:
                print(err, flush=True)
                continue
            output_rows.extend(rows)
            if idx % 25 == 0 or idx == total_files:
                print(f"[{idx}/{total_files}] {file} ok", flush=True)
        except Exception as e:
            print(f"Erro ao processar {file}: {e}", flush=True)
            continue

    out_df = pd.DataFrame(output_rows)
    out_path = os.path.join(output_folder, f"{output_csv_name}.csv")
    out_df.to_csv(out_path, index=False)
    end_ts = datetime.now().strftime("%Y%m%d_%H%M%S")
    print(f"Fim: {end_ts}")
    print(f"Dados salvos em {out_path}")
    return out_df

# -----------------------------
# Versão TURBO (paralela + grade de horas/thresholds)
# -----------------------------
def process_epw_files_grid(
    epw_folder: str,
    hours: List[int],
    thresholds: List[int],
    output_folder: str = "Output",
    base_output_name: str = "shower",
    bath_minutes: float = 1.0,
    flow_lpm: float = 4.0,
    efficiency: float = 0.95,
    temp_usage_mode: Literal["INI-R", "FIXED"] = "INI-R",
    temp_fixed_c: float = 40.0,
    delta_min_c: float = 10.0,
    ipt_csv_path: str = "IPT_Chuveiros_Eletricos.csv",
    ref_minutes_per_day: float = 8.0,
    min_flow_lpm_filter: float = 4.0,
    power_selection: Literal["ceil", "nearest"] = "ceil",
    n_workers: Optional[int] = None,
    verbose: bool = True,
    backend: Literal["auto","process","thread"] = "auto",
) -> pd.DataFrame:
    """
    Lê cada EPW uma única vez e calcula TODAS as combinações (hour x threshold),
    em paralelo por arquivo. Escreve CSVs separados por combinação.
    Feedback por cidade, e fallback automático para threads em Windows/py3.13.
    """
    north_northeast_states = {
        "AC","AP","AM","PA","RO","RR","TO",
        "AL","BA","CE","MA","PB","PE","PI","RN","SE"
    }

    ref = load_shower_reference(
        ipt_csv_path=ipt_csv_path,
        ref_minutes_per_day=ref_minutes_per_day,
        min_flow_lpm_filter=min_flow_lpm_filter,
    )
    lista_potencias_kW = ref["lista_potencias_kW"]
    curva_ref = ref["curva_ref"]

    epw_files = [os.path.join(epw_folder, f) for f in os.listdir(epw_folder) if f.lower().endswith(".epw")]
    total_files = len(epw_files)
    if total_files == 0:
        raise FileNotFoundError("Nenhum arquivo .epw encontrado.")

    os.makedirs(output_folder, exist_ok=True)

    # Define número de workers (metade dos núcleos por padrão)
    if n_workers is None:
        cpu = os.cpu_count() or 2
        n_workers = max(1, cpu // 2)

    # Backend: por padrão, usa threads no Windows ou Python >= 3.13
    if backend == "auto":
        if os.name == "nt" or sys.version_info >= (3, 13):
            backend = "thread"
        else:
            backend = "process"

    start_ts = datetime.now().strftime("%Y%m%d_%H%M%S")
    if verbose:
        preview = ", ".join([os.path.basename(p) for p in epw_files[:3]])
        if len(epw_files) > 3:
            preview += ", ..."
        print(f"Início: {start_ts} | EPWs: {total_files} | workers: {n_workers} | backend: {backend}", flush=True)
        print(f"Exemplos de arquivos: {preview}", flush=True)

    all_rows: List[Dict[str, object]] = []
    errors: List[str] = []

    def run_with_executor(use_threads: bool) -> bool:
        """Executa com ThreadPool se True; senão, ProcessPool. Retorna True se OK."""
        try:
            if use_threads:
                Executor = ThreadPoolExecutor
                ex_kwargs = {"max_workers": n_workers}
            else:
                ctx = mp.get_context("spawn")
                Executor = ProcessPoolExecutor
                ex_kwargs = {"max_workers": n_workers, "mp_context": ctx}

            with Executor(**ex_kwargs) as ex:
                future_to_path = {}
                for j, file_path in enumerate(epw_files, start=1):
                    fut = ex.submit(
                        _process_one_epw_all_combos,
                        file_path,
                        hours,
                        thresholds,
                        bath_minutes,
                        flow_lpm,
                        efficiency,
                        temp_usage_mode,
                        temp_fixed_c,
                        delta_min_c,
                        curva_ref,
                        lista_potencias_kW,
                        power_selection,
                        north_northeast_states
                    )
                    future_to_path[fut] = file_path
                    if verbose and (j % 10 == 0 or j == total_files):
                        print(f"Submetidos {j}/{total_files} arquivos...", flush=True)

                total = len(future_to_path)
                for i, fut in enumerate(as_completed(future_to_path), start=1):
                    file_path = future_to_path[fut]
                    try:
                        rows, err = fut.result()
                    except Exception as e:
                        if verbose:
                            print(f"[{i}/{total}] ERRO ao processar {os.path.basename(file_path)}: {e}", flush=True)
                        errors.append(f"ERRO {os.path.basename(file_path)}: {e}")
                        continue

                    if err:
                        errors.append(err)
                        if verbose:
                            print(err, flush=True)
                    else:
                        all_rows.extend(rows)
                        if verbose:
                            if rows:
                                city = rows[0].get("city", "Unknown")
                                state = rows[0].get("state", "??")
                            else:
                                city = os.path.basename(file_path)
                                state = "??"
                            print(f"[{i}/{total}] {city} ({state}) ok", flush=True)
            return True
        except Exception as e:
            if verbose:
                print(f"[executor] Falhou com {'threads' if use_threads else 'processos'}: {e}", flush=True)
            return False

    # Executa conforme backend definido / fallback
    ok = False
    if backend == "thread":
        ok = run_with_executor(use_threads=True)
    elif backend == "process":
        ok = run_with_executor(use_threads=False)
        if not ok and os.name == "nt":
            if verbose:
                print("Trocando para threads por estabilidade no Windows...", flush=True)
            ok = run_with_executor(use_threads=True)
    else:  # auto
        # já resolvido lá em cima; aqui por segurança
        ok = run_with_executor(use_threads=(os.name == "nt" or sys.version_info >= (3,13)))

    if not ok:
        raise RuntimeError("Falhou ao executar tanto em processos quanto em threads.")

    if errors and verbose:
        print("\nOcorreram erros em alguns arquivos:", flush=True)
        for e in errors:
            print(" -", e, flush=True)

    big_df = pd.DataFrame(all_rows)

    # Salva em CSVs separados por (hora, threshold)
    total_combos = len(hours) * len(thresholds)
    saved = 0
    for h in hours:
        for tlim in thresholds:
            df_ht = big_df[(big_df["bath_hours"] == str(h)) & (big_df["temp_limit_c"] == tlim)].copy()
            out_name = f"{base_output_name}_h{int(h):02d}_t{int(tlim)}_1min.csv"
            out_path = os.path.join(output_folder, out_name)
            df_ht.to_csv(out_path, index=False)
            saved += 1
            if verbose and (saved % 40 == 0 or saved == total_combos):
                print(f"Salvos {saved}/{total_combos} arquivos de combinação.", flush=True)

    end_ts = datetime.now().strftime("%Y%m%d_%H%M%S")
    if verbose:
        print(f"Fim: {end_ts}", flush=True)
        print(f"Arquivos salvos em: {output_folder}", flush=True)

    return big_df


# -----------------------------
# Exemplo de uso RÁPIDO
# -----------------------------
if __name__ == "__main__":
    # Suporte a Windows/Notebook
    try:
        mp.freeze_support()
        try:
            mp.set_start_method("spawn", force=False)
        except RuntimeError:
            pass
    except Exception:
        pass

    epw_folder = "EPW_files"
    output_folder = "Output"
    os.makedirs(output_folder, exist_ok=True)

    # Todas as horas cheias (0..23) e thresholds (15..40)
    todas_as_horas = list(range(24))
    todos_thresholds = list(range(15, 41))

    banho_minutos = 1.0

    # Metade dos núcleos por padrão
    half_cores = max(1, (os.cpu_count() or 2) // 2)

    process_epw_files_grid(
        epw_folder=epw_folder,
        hours=todas_as_horas,
        thresholds=todos_thresholds,
        output_folder=output_folder,
        base_output_name="shower",
        bath_minutes=banho_minutos,
        flow_lpm=4.0,
        efficiency=0.95,
        temp_usage_mode="INI-R",
        temp_fixed_c=40.0,
        delta_min_c=10.0,
        ipt_csv_path="IPT_Chuveiros_Eletricos.csv",
        ref_minutes_per_day=8.0,
        min_flow_lpm_filter=4.0,
        power_selection="ceil",
        n_workers=half_cores,
        verbose=True,
        backend="auto",   # em Windows/py3.13 vira 'thread' automaticamente
    )
# Out:
# Início: 20250809_112114 | EPWs: 5202 | workers: 10 | backend: thread
# Exemplos de arquivos: BRA_AC_Cruzeiro.do.Sul.Intl.AP.827040_TMYx.2007-2021.epw, BRA_AC_Cruzeiro.do.Sul.Intl.AP_Ensemble_ssp126_2050.epw, BRA_AC_Cruzeiro.do.Sul.Intl.AP_Ensemble_ssp126_2080.epw, ...
# Submetidos 10/5202 arquivos...
# Submetidos 20/5202 arquivos...
# Submetidos 30/5202 arquivos...
# Submetidos 40/5202 arquivos...
# Submetidos 50/5202 arquivos...
# Submetidos 60/5202 arquivos...
# Submetidos 70/5202 arquivos...
# Submetidos 80/5202 arquivos...
# Submetidos 90/5202 arquivos...
# Submetidos 100/5202 arquivos...
# Submetidos 110/5202 arquivos...
# Submetidos 120/5202 arquivos...
# Submetidos 130/5202 arquivos...
# Submetidos 140/5202 arquivos...
# Submetidos 150/5202 arquivos...
# Submetidos 160/5202 arquivos...
# Submetidos 170/5202 arquivos...
# Submetidos 180/5202 arquivos...
# Submetidos 190/5202 arquivos...
# Submetidos 200/5202 arquivos...
# Submetidos 210/5202 arquivos...
# Submetidos 220/5202 arquivos...
# Submetidos 230/5202 arquivos...
# Submetidos 240/5202 arquivos...
# Submetidos 250/5202 arquivos...
# Submetidos 260/5202 arquivos...
# Submetidos 270/5202 arquivos...
# Submetidos 280/5202 arquivos...
# Submetidos 290/5202 arquivos...
# Submetidos 300/5202 arquivos...
# Submetidos 310/5202 arquivos...
# Submetidos 320/5202 arquivos...
# Submetidos 330/5202 arquivos...
# Submetidos 340/5202 arquivos...
# Submetidos 350/5202 arquivos...
# Submetidos 360/5202 arquivos...
# Submetidos 370/5202 arquivos...
# Submetidos 380/5202 arquivos...
# Submetidos 390/5202 arquivos...
# Submetidos 400/5202 arquivos...
# Submetidos 410/5202 arquivos...
# Submetidos 420/5202 arquivos...
# Submetidos 430/5202 arquivos...
# Submetidos 440/5202 arquivos...
# Submetidos 450/5202 arquivos...
# Submetidos 460/5202 arquivos...
# Submetidos 470/5202 arquivos...
# Submetidos 480/5202 arquivos...
# Submetidos 490/5202 arquivos...
# Submetidos 500/5202 arquivos...
# Submetidos 510/5202 arquivos...
# Submetidos 520/5202 arquivos...
# Submetidos 530/5202 arquivos...
# Submetidos 540/5202 arquivos...
# Submetidos 550/5202 arquivos...
# Submetidos 560/5202 arquivos...
# Submetidos 570/5202 arquivos...
# Submetidos 580/5202 arquivos...
# Submetidos 590/5202 arquivos...
# Submetidos 600/5202 arquivos...
# Submetidos 610/5202 arquivos...
# Submetidos 620/5202 arquivos...
# Submetidos 630/5202 arquivos...
# Submetidos 640/5202 arquivos...
# Submetidos 650/5202 arquivos...
# Submetidos 660/5202 arquivos...
# Submetidos 670/5202 arquivos...
# Submetidos 680/5202 arquivos...
# Submetidos 690/5202 arquivos...
# Submetidos 700/5202 arquivos...
# Submetidos 710/5202 arquivos...
# Submetidos 720/5202 arquivos...
# Submetidos 730/5202 arquivos...
# Submetidos 740/5202 arquivos...
# Submetidos 750/5202 arquivos...
# Submetidos 760/5202 arquivos...
# Submetidos 770/5202 arquivos...
# Submetidos 780/5202 arquivos...
# Submetidos 790/5202 arquivos...
# Submetidos 800/5202 arquivos...
# Submetidos 810/5202 arquivos...
# Submetidos 820/5202 arquivos...
# Submetidos 830/5202 arquivos...
# Submetidos 840/5202 arquivos...
# Submetidos 850/5202 arquivos...
# Submetidos 860/5202 arquivos...
# Submetidos 870/5202 arquivos...
# Submetidos 880/5202 arquivos...
# Submetidos 890/5202 arquivos...
# Submetidos 900/5202 arquivos...
# Submetidos 910/5202 arquivos...
# Submetidos 920/5202 arquivos...
# Submetidos 930/5202 arquivos...
# Submetidos 940/5202 arquivos...
# Submetidos 950/5202 arquivos...
# Submetidos 960/5202 arquivos...
# Submetidos 970/5202 arquivos...
# Submetidos 980/5202 arquivos...
# Submetidos 990/5202 arquivos...
# Submetidos 1000/5202 arquivos...
# Submetidos 1010/5202 arquivos...
# Submetidos 1020/5202 arquivos...
# Submetidos 1030/5202 arquivos...
# Submetidos 1040/5202 arquivos...
# Submetidos 1050/5202 arquivos...
# Submetidos 1060/5202 arquivos...
# Submetidos 1070/5202 arquivos...
# Submetidos 1080/5202 arquivos...
# Submetidos 1090/5202 arquivos...
# Submetidos 1100/5202 arquivos...
# Submetidos 1110/5202 arquivos...
# Submetidos 1120/5202 arquivos...
# Submetidos 1130/5202 arquivos...
# Submetidos 1140/5202 arquivos...
# Submetidos 1150/5202 arquivos...
# Submetidos 1160/5202 arquivos...
# Submetidos 1170/5202 arquivos...
# Submetidos 1180/5202 arquivos...
# Submetidos 1190/5202 arquivos...
# Submetidos 1200/5202 arquivos...
# Submetidos 1210/5202 arquivos...
# Submetidos 1220/5202 arquivos...
# Submetidos 1230/5202 arquivos...
# Submetidos 1240/5202 arquivos...
# Submetidos 1250/5202 arquivos...
# Submetidos 1260/5202 arquivos...
# Submetidos 1270/5202 arquivos...
# Submetidos 1280/5202 arquivos...
# Submetidos 1290/5202 arquivos...
# Submetidos 1300/5202 arquivos...
# Submetidos 1310/5202 arquivos...
# Submetidos 1320/5202 arquivos...
# Submetidos 1330/5202 arquivos...
# Submetidos 1340/5202 arquivos...
# Submetidos 1350/5202 arquivos...
# Submetidos 1360/5202 arquivos...
# Submetidos 1370/5202 arquivos...
# Submetidos 1380/5202 arquivos...
# Submetidos 1390/5202 arquivos...
# Submetidos 1400/5202 arquivos...
# Submetidos 1410/5202 arquivos...
# Submetidos 1420/5202 arquivos...
# Submetidos 1430/5202 arquivos...
# Submetidos 1440/5202 arquivos...
# Submetidos 1450/5202 arquivos...
# Submetidos 1460/5202 arquivos...
# Submetidos 1470/5202 arquivos...
# Submetidos 1480/5202 arquivos...
# Submetidos 1490/5202 arquivos...
# Submetidos 1500/5202 arquivos...
# Submetidos 1510/5202 arquivos...
# Submetidos 1520/5202 arquivos...
# Submetidos 1530/5202 arquivos...
# Submetidos 1540/5202 arquivos...
# Submetidos 1550/5202 arquivos...
# Submetidos 1560/5202 arquivos...
# Submetidos 1570/5202 arquivos...
# Submetidos 1580/5202 arquivos...
# Submetidos 1590/5202 arquivos...
# Submetidos 1600/5202 arquivos...
# Submetidos 1610/5202 arquivos...
# Submetidos 1620/5202 arquivos...
# Submetidos 1630/5202 arquivos...
# Submetidos 1640/5202 arquivos...
# Submetidos 1650/5202 arquivos...
# Submetidos 1660/5202 arquivos...
# Submetidos 1670/5202 arquivos...
# Submetidos 1680/5202 arquivos...
# Submetidos 1690/5202 arquivos...
# Submetidos 1700/5202 arquivos...
# Submetidos 1710/5202 arquivos...
# Submetidos 1720/5202 arquivos...
# Submetidos 1730/5202 arquivos...
# Submetidos 1740/5202 arquivos...
# Submetidos 1750/5202 arquivos...
# Submetidos 1760/5202 arquivos...
# Submetidos 1770/5202 arquivos...
# Submetidos 1780/5202 arquivos...
# Submetidos 1790/5202 arquivos...
# Submetidos 1800/5202 arquivos...
# Submetidos 1810/5202 arquivos...
# Submetidos 1820/5202 arquivos...
# Submetidos 1830/5202 arquivos...
# Submetidos 1840/5202 arquivos...
# Submetidos 1850/5202 arquivos...
# Submetidos 1860/5202 arquivos...
# Submetidos 1870/5202 arquivos...
# Submetidos 1880/5202 arquivos...
# Submetidos 1890/5202 arquivos...
# Submetidos 1900/5202 arquivos...
# Submetidos 1910/5202 arquivos...
# Submetidos 1920/5202 arquivos...
# Submetidos 1930/5202 arquivos...
# Submetidos 1940/5202 arquivos...
# Submetidos 1950/5202 arquivos...
# Submetidos 1960/5202 arquivos...
# Submetidos 1970/5202 arquivos...
# Submetidos 1980/5202 arquivos...
# Submetidos 1990/5202 arquivos...
# Submetidos 2000/5202 arquivos...
# Submetidos 2010/5202 arquivos...
# Submetidos 2020/5202 arquivos...
# Submetidos 2030/5202 arquivos...
# Submetidos 2040/5202 arquivos...
# Submetidos 2050/5202 arquivos...
# Submetidos 2060/5202 arquivos...
# Submetidos 2070/5202 arquivos...
# Submetidos 2080/5202 arquivos...
# Submetidos 2090/5202 arquivos...
# Submetidos 2100/5202 arquivos...
# Submetidos 2110/5202 arquivos...
# Submetidos 2120/5202 arquivos...
# Submetidos 2130/5202 arquivos...
# Submetidos 2140/5202 arquivos...
# Submetidos 2150/5202 arquivos...
# Submetidos 2160/5202 arquivos...
# Submetidos 2170/5202 arquivos...
# Submetidos 2180/5202 arquivos...
# Submetidos 2190/5202 arquivos...
# Submetidos 2200/5202 arquivos...
# Submetidos 2210/5202 arquivos...
# Submetidos 2220/5202 arquivos...
# Submetidos 2230/5202 arquivos...
# Submetidos 2240/5202 arquivos...
# Submetidos 2250/5202 arquivos...
# Submetidos 2260/5202 arquivos...
# Submetidos 2270/5202 arquivos...
# Submetidos 2280/5202 arquivos...
# Submetidos 2290/5202 arquivos...
# Submetidos 2300/5202 arquivos...
# Submetidos 2310/5202 arquivos...
# Submetidos 2320/5202 arquivos...
# Submetidos 2330/5202 arquivos...
# Submetidos 2340/5202 arquivos...
# Submetidos 2350/5202 arquivos...
# Submetidos 2360/5202 arquivos...
# Submetidos 2370/5202 arquivos...
# Submetidos 2380/5202 arquivos...
# Submetidos 2390/5202 arquivos...
# Submetidos 2400/5202 arquivos...
# Submetidos 2410/5202 arquivos...
# Submetidos 2420/5202 arquivos...
# Submetidos 2430/5202 arquivos...
# Submetidos 2440/5202 arquivos...
# Submetidos 2450/5202 arquivos...
# Submetidos 2460/5202 arquivos...
# Submetidos 2470/5202 arquivos...
# Submetidos 2480/5202 arquivos...
# Submetidos 2490/5202 arquivos...
# Submetidos 2500/5202 arquivos...
# Submetidos 2510/5202 arquivos...
# Submetidos 2520/5202 arquivos...
# Submetidos 2530/5202 arquivos...
# Submetidos 2540/5202 arquivos...
# Submetidos 2550/5202 arquivos...
# Submetidos 2560/5202 arquivos...
# Submetidos 2570/5202 arquivos...
# Submetidos 2580/5202 arquivos...
# Submetidos 2590/5202 arquivos...
# Submetidos 2600/5202 arquivos...
# Submetidos 2610/5202 arquivos...
# Submetidos 2620/5202 arquivos...
# Submetidos 2630/5202 arquivos...
# Submetidos 2640/5202 arquivos...
# Submetidos 2650/5202 arquivos...
# Submetidos 2660/5202 arquivos...
# Submetidos 2670/5202 arquivos...
# Submetidos 2680/5202 arquivos...
# Submetidos 2690/5202 arquivos...
# Submetidos 2700/5202 arquivos...
# Submetidos 2710/5202 arquivos...
# Submetidos 2720/5202 arquivos...
# Submetidos 2730/5202 arquivos...
# Submetidos 2740/5202 arquivos...
# Submetidos 2750/5202 arquivos...
# Submetidos 2760/5202 arquivos...
# Submetidos 2770/5202 arquivos...
# Submetidos 2780/5202 arquivos...
# Submetidos 2790/5202 arquivos...
# Submetidos 2800/5202 arquivos...
# Submetidos 2810/5202 arquivos...
# Submetidos 2820/5202 arquivos...
# Submetidos 2830/5202 arquivos...
# Submetidos 2840/5202 arquivos...
# Submetidos 2850/5202 arquivos...
# Submetidos 2860/5202 arquivos...
# Submetidos 2870/5202 arquivos...
# Submetidos 2880/5202 arquivos...
# Submetidos 2890/5202 arquivos...
# Submetidos 2900/5202 arquivos...
# Submetidos 2910/5202 arquivos...
# Submetidos 2920/5202 arquivos...
# Submetidos 2930/5202 arquivos...
# Submetidos 2940/5202 arquivos...
# Submetidos 2950/5202 arquivos...
# Submetidos 2960/5202 arquivos...
# Submetidos 2970/5202 arquivos...
# Submetidos 2980/5202 arquivos...
# Submetidos 2990/5202 arquivos...
# Submetidos 3000/5202 arquivos...
# Submetidos 3010/5202 arquivos...
# Submetidos 3020/5202 arquivos...
# Submetidos 3030/5202 arquivos...
# Submetidos 3040/5202 arquivos...
# Submetidos 3050/5202 arquivos...
# Submetidos 3060/5202 arquivos...
# Submetidos 3070/5202 arquivos...
# Submetidos 3080/5202 arquivos...
# Submetidos 3090/5202 arquivos...
# Submetidos 3100/5202 arquivos...
# Submetidos 3110/5202 arquivos...
# Submetidos 3120/5202 arquivos...
# Submetidos 3130/5202 arquivos...
# Submetidos 3140/5202 arquivos...
# Submetidos 3150/5202 arquivos...
# Submetidos 3160/5202 arquivos...
# Submetidos 3170/5202 arquivos...
# Submetidos 3180/5202 arquivos...
# Submetidos 3190/5202 arquivos...
# Submetidos 3200/5202 arquivos...
# Submetidos 3210/5202 arquivos...
# Submetidos 3220/5202 arquivos...
# Submetidos 3230/5202 arquivos...
# Submetidos 3240/5202 arquivos...
# Submetidos 3250/5202 arquivos...
# Submetidos 3260/5202 arquivos...
# Submetidos 3270/5202 arquivos...
# Submetidos 3280/5202 arquivos...
# Submetidos 3290/5202 arquivos...
# Submetidos 3300/5202 arquivos...
# Submetidos 3310/5202 arquivos...
# Submetidos 3320/5202 arquivos...
# Submetidos 3330/5202 arquivos...
# Submetidos 3340/5202 arquivos...
# Submetidos 3350/5202 arquivos...
# Submetidos 3360/5202 arquivos...
# Submetidos 3370/5202 arquivos...
# Submetidos 3380/5202 arquivos...
# Submetidos 3390/5202 arquivos...
# Submetidos 3400/5202 arquivos...
# Submetidos 3410/5202 arquivos...
# Submetidos 3420/5202 arquivos...
# Submetidos 3430/5202 arquivos...
# Submetidos 3440/5202 arquivos...
# Submetidos 3450/5202 arquivos...
# Submetidos 3460/5202 arquivos...
# Submetidos 3470/5202 arquivos...
# Submetidos 3480/5202 arquivos...
# Submetidos 3490/5202 arquivos...
# Submetidos 3500/5202 arquivos...
# Submetidos 3510/5202 arquivos...
# Submetidos 3520/5202 arquivos...
# Submetidos 3530/5202 arquivos...
# Submetidos 3540/5202 arquivos...
# Submetidos 3550/5202 arquivos...
# Submetidos 3560/5202 arquivos...
# Submetidos 3570/5202 arquivos...
# Submetidos 3580/5202 arquivos...
# Submetidos 3590/5202 arquivos...
# Submetidos 3600/5202 arquivos...
# Submetidos 3610/5202 arquivos...
# Submetidos 3620/5202 arquivos...
# Submetidos 3630/5202 arquivos...
# Submetidos 3640/5202 arquivos...
# Submetidos 3650/5202 arquivos...
# Submetidos 3660/5202 arquivos...
# Submetidos 3670/5202 arquivos...
# Submetidos 3680/5202 arquivos...
# Submetidos 3690/5202 arquivos...
# Submetidos 3700/5202 arquivos...
# Submetidos 3710/5202 arquivos...
# Submetidos 3720/5202 arquivos...
# Submetidos 3730/5202 arquivos...
# Submetidos 3740/5202 arquivos...
# Submetidos 3750/5202 arquivos...
# Submetidos 3760/5202 arquivos...
# Submetidos 3770/5202 arquivos...
# Submetidos 3780/5202 arquivos...
# Submetidos 3790/5202 arquivos...
# Submetidos 3800/5202 arquivos...
# Submetidos 3810/5202 arquivos...
# Submetidos 3820/5202 arquivos...
# Submetidos 3830/5202 arquivos...
# Submetidos 3840/5202 arquivos...
# Submetidos 3850/5202 arquivos...
# Submetidos 3860/5202 arquivos...
# Submetidos 3870/5202 arquivos...
# Submetidos 3880/5202 arquivos...
# Submetidos 3890/5202 arquivos...
# Submetidos 3900/5202 arquivos...
# Submetidos 3910/5202 arquivos...
# Submetidos 3920/5202 arquivos...
# Submetidos 3930/5202 arquivos...
# Submetidos 3940/5202 arquivos...
# Submetidos 3950/5202 arquivos...
# Submetidos 3960/5202 arquivos...
# Submetidos 3970/5202 arquivos...
# Submetidos 3980/5202 arquivos...
# Submetidos 3990/5202 arquivos...
# Submetidos 4000/5202 arquivos...
# Submetidos 4010/5202 arquivos...
# Submetidos 4020/5202 arquivos...
# Submetidos 4030/5202 arquivos...
# Submetidos 4040/5202 arquivos...
# Submetidos 4050/5202 arquivos...
# Submetidos 4060/5202 arquivos...
# Submetidos 4070/5202 arquivos...
# Submetidos 4080/5202 arquivos...
# Submetidos 4090/5202 arquivos...
# Submetidos 4100/5202 arquivos...
# Submetidos 4110/5202 arquivos...
# Submetidos 4120/5202 arquivos...
# Submetidos 4130/5202 arquivos...
# Submetidos 4140/5202 arquivos...
# Submetidos 4150/5202 arquivos...
# Submetidos 4160/5202 arquivos...
# Submetidos 4170/5202 arquivos...
# Submetidos 4180/5202 arquivos...
# Submetidos 4190/5202 arquivos...
# Submetidos 4200/5202 arquivos...
# Submetidos 4210/5202 arquivos...
# Submetidos 4220/5202 arquivos...
# Submetidos 4230/5202 arquivos...
# Submetidos 4240/5202 arquivos...
# Submetidos 4250/5202 arquivos...
# Submetidos 4260/5202 arquivos...
# Submetidos 4270/5202 arquivos...
# Submetidos 4280/5202 arquivos...
# Submetidos 4290/5202 arquivos...
# Submetidos 4300/5202 arquivos...
# Submetidos 4310/5202 arquivos...
# Submetidos 4320/5202 arquivos...
# Submetidos 4330/5202 arquivos...
# Submetidos 4340/5202 arquivos...
# Submetidos 4350/5202 arquivos...
# Submetidos 4360/5202 arquivos...
# Submetidos 4370/5202 arquivos...
# Submetidos 4380/5202 arquivos...
# Submetidos 4390/5202 arquivos...
# Submetidos 4400/5202 arquivos...
# Submetidos 4410/5202 arquivos...
# Submetidos 4420/5202 arquivos...
# Submetidos 4430/5202 arquivos...
# Submetidos 4440/5202 arquivos...
# Submetidos 4450/5202 arquivos...
# Submetidos 4460/5202 arquivos...
# Submetidos 4470/5202 arquivos...
# Submetidos 4480/5202 arquivos...
# Submetidos 4490/5202 arquivos...
# Submetidos 4500/5202 arquivos...
# Submetidos 4510/5202 arquivos...
# Submetidos 4520/5202 arquivos...
# Submetidos 4530/5202 arquivos...
# Submetidos 4540/5202 arquivos...
# Submetidos 4550/5202 arquivos...
# Submetidos 4560/5202 arquivos...
# Submetidos 4570/5202 arquivos...
# Submetidos 4580/5202 arquivos...
# Submetidos 4590/5202 arquivos...
# Submetidos 4600/5202 arquivos...
# Submetidos 4610/5202 arquivos...
# Submetidos 4620/5202 arquivos...
# Submetidos 4630/5202 arquivos...
# Submetidos 4640/5202 arquivos...
# Submetidos 4650/5202 arquivos...
# Submetidos 4660/5202 arquivos...
# Submetidos 4670/5202 arquivos...
# Submetidos 4680/5202 arquivos...
# Submetidos 4690/5202 arquivos...
# Submetidos 4700/5202 arquivos...
# Submetidos 4710/5202 arquivos...
# Submetidos 4720/5202 arquivos...
# Submetidos 4730/5202 arquivos...
# Submetidos 4740/5202 arquivos...
# Submetidos 4750/5202 arquivos...
# Submetidos 4760/5202 arquivos...
# Submetidos 4770/5202 arquivos...
# Submetidos 4780/5202 arquivos...
# Submetidos 4790/5202 arquivos...
# Submetidos 4800/5202 arquivos...
# Submetidos 4810/5202 arquivos...
# Submetidos 4820/5202 arquivos...
# Submetidos 4830/5202 arquivos...
# Submetidos 4840/5202 arquivos...
# Submetidos 4850/5202 arquivos...
# Submetidos 4860/5202 arquivos...
# Submetidos 4870/5202 arquivos...
# Submetidos 4880/5202 arquivos...
# Submetidos 4890/5202 arquivos...
# Submetidos 4900/5202 arquivos...
# Submetidos 4910/5202 arquivos...
# Submetidos 4920/5202 arquivos...
# Submetidos 4930/5202 arquivos...
# Submetidos 4940/5202 arquivos...
# Submetidos 4950/5202 arquivos...
# Submetidos 4960/5202 arquivos...
# Submetidos 4970/5202 arquivos...
# Submetidos 4980/5202 arquivos...
# Submetidos 4990/5202 arquivos...
# Submetidos 5000/5202 arquivos...
# Submetidos 5010/5202 arquivos...
# Submetidos 5020/5202 arquivos...
# Submetidos 5030/5202 arquivos...
# Submetidos 5040/5202 arquivos...
# Submetidos 5050/5202 arquivos...
# Submetidos 5060/5202 arquivos...
# Submetidos 5070/5202 arquivos...
# Submetidos 5080/5202 arquivos...
# Submetidos 5090/5202 arquivos...
# Submetidos 5100/5202 arquivos...
# Submetidos 5110/5202 arquivos...
# Submetidos 5120/5202 arquivos...
# Submetidos 5130/5202 arquivos...
# Submetidos 5140/5202 arquivos...
# Submetidos 5150/5202 arquivos...
# Submetidos 5160/5202 arquivos...
# Submetidos 5170/5202 arquivos...
# Submetidos 5180/5202 arquivos...
# Submetidos 5190/5202 arquivos...
# Submetidos 5200/5202 arquivos...
# Submetidos 5202/5202 arquivos...
# [1/5202] Cruzeiro.do.Sul.Intl.AP (AC) ok
# [2/5202] Feijo.AP (AC) ok
# [3/5202] Epitaciolandia (AC) ok
# [4/5202] Cruzeiro.do.Sul.Intl.AP (AC) ok
# [5/5202] Feijo.AP (AC) ok
# [6/5202] Cruzeiro.do.Sul.Intl.AP (AC) ok
# [7/5202] Epitaciolandia (AC) ok
# [8/5202] Epitaciolandia (AC) ok
# [9/5202] Cruzeiro.do.Sul.Intl.AP (AC) ok
# [10/5202] Epitaciolandia (AC) ok
# [11/5202] Cruzeiro.do.Sul.Intl.AP (AC) ok
# [12/5202] Cruzeiro.do.Sul.Intl.AP (AC) ok
# [13/5202] Epitaciolandia (AC) ok
# [14/5202] Epitaciolandia (AC) ok
# [15/5202] Epitaciolandia (AC) ok
# [16/5202] Cruzeiro.do.Sul.Intl.AP (AC) ok
# [17/5202] Epitaciolandia (AC) ok
# [18/5202] Cruzeiro.do.Sul.Intl.AP (AC) ok
# [19/5202] Epitaciolandia (AC) ok
# [20/5202] Cruzeiro.do.Sul.Intl.AP (AC) ok
# [21/5202] Feijo.AP (AC) ok
# [22/5202] Feijo.AP (AC) ok
# [23/5202] Feijo.AP (AC) ok
# [24/5202] Feijo.AP (AC) ok
# [25/5202] Feijo.AP (AC) ok
# [26/5202] Feijo.AP (AC) ok
# [27/5202] Parque.Estadual.Chandless (AC) ok
# [28/5202] Feijo.AP (AC) ok
# [29/5202] Parque.Estadual.Chandless (AC) ok
# [30/5202] Parque.Estadual.Chandless (AC) ok
# [31/5202] Parque.Estadual.Chandless (AC) ok
# [32/5202] Parque.Estadual.Chandless (AC) ok
# [33/5202] Parque.Estadual.Chandless (AC) ok
# [34/5202] Parque.Estadual.Chandless (AC) ok
# [35/5202] Parque.Estadual.Chandless (AC) ok
# [36/5202] Parque.Estadual.Chandless (AC) ok
# [37/5202] Porto.Walter (AC) ok
# [38/5202] Porto.Walter (AC) ok
# [39/5202] Porto.Walter (AC) ok
# [40/5202] Porto.Walter (AC) ok
# [41/5202] Porto.Walter (AC) ok
# [42/5202] Porto.Walter (AC) ok
# [43/5202] Porto.Walter (AC) ok
# [44/5202] Porto.Walter (AC) ok
# [45/5202] Porto.Walter (AC) ok
# [46/5202] Rio.Branco-Medici.Intl.AP (AC) ok
# [47/5202] Rio.Branco-Medici.Intl.AP (AC) ok
# [48/5202] Rio.Branco-Medici.Intl.AP (AC) ok
# [49/5202] Rio.Branco-Medici.Intl.AP (AC) ok
# [50/5202] Rio.Branco-Medici.Intl.AP (AC) ok
# [51/5202] Rio.Branco-Medici.Intl.AP (AC) ok
# [52/5202] Rio.Branco-Medici.Intl.AP (AC) ok
# [53/5202] Rio.Branco-Medici.Intl.AP (AC) ok
# [54/5202] Rio.Branco-Medici.Intl.AP (AC) ok
# [55/5202] Tarauaca.AP (AC) ok
# [56/5202] Tarauaca.AP (AC) ok
# [57/5202] Tarauaca.AP (AC) ok
# [58/5202] Tarauaca.AP (AC) ok
# [59/5202] Tarauaca.AP (AC) ok
# [60/5202] Tarauaca.AP (AC) ok
# [61/5202] Tarauaca.AP (AC) ok
# [62/5202] Tarauaca.AP (AC) ok
# [63/5202] Tarauaca.AP (AC) ok
# [64/5202] Arapiraca.AP (AL) ok
# [666/5202] Lencois (BA) ok
# [667/5202] Luis.Eduardo.Magalhaes (BA) ok
# [668/5202] Luis.Eduardo.Magalhaes (BA) ok
# [669/5202] Luis.Eduardo.Magalhaes (BA) ok
# [670/5202] Luis.Eduardo.Magalhaes (BA) ok
# [671/5202] Luis.Eduardo.Magalhaes (BA) ok
# [672/5202] Luis.Eduardo.Magalhaes (BA) ok
# [673/5202] Luis.Eduardo.Magalhaes (BA) ok
# [674/5202] Luis.Eduardo.Magalhaes (BA) ok
# [675/5202] Luis.Eduardo.Magalhaes (BA) ok
# [676/5202] Macajuba (BA) ok
# [677/5202] Macajuba (BA) ok
# [678/5202] Macajuba (BA) ok
# [679/5202] Macajuba (BA) ok
# [680/5202] Macajuba (BA) ok
# [681/5202] Macajuba (BA) ok
# [682/5202] Macajuba (BA) ok
# [683/5202] Macajuba (BA) ok
# [684/5202] Macajuba (BA) ok
# [685/5202] Marau (BA) ok
# [686/5202] Marau (BA) ok
# [687/5202] Marau (BA) ok
# [688/5202] Marau (BA) ok
# [689/5202] Marau (BA) ok
# [690/5202] Marau (BA) ok
# [691/5202] Marau (BA) ok
# [692/5202] Marau (BA) ok
# [693/5202] Marau (BA) ok
# [694/5202] Paulo.Afonso.AP (BA) ok
# [695/5202] Paulo.Afonso.AP (BA) ok
# [696/5202] Paulo.Afonso.AP (BA) ok
# [697/5202] Paulo.Afonso.AP (BA) ok
# [698/5202] Paulo.Afonso.AP (BA) ok
# [699/5202] Paulo.Afonso.AP (BA) ok
# [700/5202] Paulo.Afonso.AP (BA) ok
# [701/5202] Paulo.Afonso.AP (BA) ok
# [702/5202] Paulo.Afonso.AP (BA) ok
# [703/5202] Piata (BA) ok
# [704/5202] Piata (BA) ok
# [705/5202] Piata (BA) ok
# [706/5202] Piata (BA) ok
# [707/5202] Piata (BA) ok
# [708/5202] Piata (BA) ok
# [709/5202] Piata (BA) ok
# [710/5202] Piata (BA) ok
# [711/5202] Porto.Seguro-Brazil.Ecological.Stn (BA) ok
# [712/5202] Piata (BA) ok
# [713/5202] Porto.Seguro-Brazil.Ecological.Stn (BA) ok
# [714/5202] Porto.Seguro-Brazil.Ecological.Stn (BA) ok
# [715/5202] Porto.Seguro-Brazil.Ecological.Stn (BA) ok
# [716/5202] Porto.Seguro-Brazil.Ecological.Stn (BA) ok
# [717/5202] Porto.Seguro-Brazil.Ecological.Stn (BA) ok
# [718/5202] Porto.Seguro-Brazil.Ecological.Stn (BA) ok
# [719/5202] Porto.Seguro-Brazil.Ecological.Stn (BA) ok
# [720/5202] Porto.Seguro-Brazil.Ecological.Stn (BA) ok
# [721/5202] Porto.Seguro.Intl.AP (BA) ok
# [722/5202] Porto.Seguro.Intl.AP (BA) ok
# [723/5202] Porto.Seguro.Intl.AP (BA) ok
# [724/5202] Porto.Seguro.Intl.AP (BA) ok
# [725/5202] Porto.Seguro.Intl.AP (BA) ok
# [726/5202] Porto.Seguro.Intl.AP (BA) ok
# [727/5202] Porto.Seguro.Intl.AP (BA) ok
# [728/5202] Porto.Seguro.Intl.AP (BA) ok
# [729/5202] Porto.Seguro.Intl.AP (BA) ok
# [730/5202] Queimadas (BA) ok
# [731/5202] Queimadas (BA) ok
# [732/5202] Queimadas (BA) ok
# [733/5202] Queimadas (BA) ok
# [734/5202] Queimadas (BA) ok
# [735/5202] Queimadas (BA) ok
# [736/5202] Queimadas (BA) ok
# [737/5202] Queimadas (BA) ok
# [738/5202] Queimadas (BA) ok
# [739/5202] Remanso (BA) ok
# [740/5202] Remanso (BA) ok
# [741/5202] Remanso (BA) ok
# [742/5202] Remanso (BA) ok
# [743/5202] Remanso (BA) ok
# [744/5202] Remanso (BA) ok
# [745/5202] Remanso (BA) ok
# [746/5202] Remanso (BA) ok
# [747/5202] Remanso (BA) ok
# [748/5202] Salvador-Magalhaes.Intl.AP (BA) ok
# [749/5202] Salvador-Magalhaes.Intl.AP (BA) ok
# [750/5202] Salvador-Magalhaes.Intl.AP (BA) ok
# [751/5202] Salvador-Magalhaes.Intl.AP (BA) ok
# [752/5202] Salvador-Magalhaes.Intl.AP (BA) ok
# [753/5202] Salvador-Magalhaes.Intl.AP (BA) ok
# [754/5202] Salvador-Magalhaes.Intl.AP (BA) ok
# [755/5202] Salvador-Magalhaes.Intl.AP (BA) ok
# [756/5202] Salvador-Magalhaes.Intl.AP (BA) ok
# [757/5202] Salvador (BA) ok
# [758/5202] Salvador (BA) ok
# [759/5202] Salvador (BA) ok
# [760/5202] Salvador (BA) ok
# [761/5202] Salvador (BA) ok
# [762/5202] Salvador (BA) ok
# [763/5202] Salvador (BA) ok
# [764/5202] Salvador (BA) ok
# [765/5202] Salvador (BA) ok
# [766/5202] Santa.Rita.de.Cassia (BA) ok
# [767/5202] Santa.Rita.de.Cassia (BA) ok
# [768/5202] Santa.Rita.de.Cassia (BA) ok
# [769/5202] Santa.Rita.de.Cassia (BA) ok
# [770/5202] Santa.Rita.de.Cassia (BA) ok
# [771/5202] Santa.Rita.de.Cassia (BA) ok
# [772/5202] Santa.Rita.de.Cassia (BA) ok
# [773/5202] Santa.Rita.de.Cassia (BA) ok
# [774/5202] Santa.Rita.de.Cassia (BA) ok
# [775/5202] Senhor.do.Bonfim (BA) ok
# [776/5202] Senhor.do.Bonfim (BA) ok
# [777/5202] Senhor.do.Bonfim (BA) ok
# [778/5202] Senhor.do.Bonfim (BA) ok
# [779/5202] Senhor.do.Bonfim (BA) ok
# [780/5202] Senhor.do.Bonfim (BA) ok
# [781/5202] Senhor.do.Bonfim (BA) ok
# [782/5202] Senhor.do.Bonfim (BA) ok
# [783/5202] Senhor.do.Bonfim (BA) ok
# [784/5202] Serrinha (BA) ok
# [785/5202] Serrinha (BA) ok
# [786/5202] Serrinha (BA) ok
# [787/5202] Serrinha (BA) ok
# [788/5202] Serrinha (BA) ok
# [789/5202] Serrinha (BA) ok
# [790/5202] Serrinha (BA) ok
# [791/5202] Serrinha (BA) ok
# [792/5202] Serrinha (BA) ok
# [793/5202] Uaua (BA) ok
# [794/5202] Uaua (BA) ok
# [795/5202] Uaua (BA) ok
# [796/5202] Uaua (BA) ok
# [797/5202] Uaua (BA) ok
# [798/5202] Uaua (BA) ok
# [799/5202] Uaua (BA) ok
# [800/5202] Uaua (BA) ok
# [801/5202] Uaua (BA) ok
# [802/5202] Vitoria.da.Conquista-Figueiredo.AP (BA) ok
# [803/5202] Vitoria.da.Conquista-Figueiredo.AP (BA) ok
# [804/5202] Vitoria.da.Conquista-Figueiredo.AP (BA) ok
# [805/5202] Vitoria.da.Conquista-Figueiredo.AP (BA) ok
# [806/5202] Vitoria.da.Conquista-Figueiredo.AP (BA) ok
# [807/5202] Vitoria.da.Conquista-Figueiredo.AP (BA) ok
# [808/5202] Vitoria.da.Conquista-Figueiredo.AP (BA) ok
# [809/5202] Vitoria.da.Conquista-Figueiredo.AP (BA) ok
# [810/5202] Vitoria.da.Conquista-Figueiredo.AP (BA) ok
# [811/5202] Vitoria.da.Conquista (BA) ok
# [812/5202] Vitoria.da.Conquista (BA) ok
# [813/5202] Vitoria.da.Conquista (BA) ok
# [814/5202] Vitoria.da.Conquista (BA) ok
# [815/5202] Vitoria.da.Conquista (BA) ok
# [816/5202] Vitoria.da.Conquista (BA) ok
# [817/5202] Acarau (CE) ok
# [818/5202] Acarau (CE) ok
# [819/5202] Vitoria.da.Conquista (BA) ok
# [820/5202] Vitoria.da.Conquista (BA) ok
# [821/5202] Acarau (CE) ok
# [5150/5202] Parana (TO) ok
# [5151/5202] Parana (TO) ok
# [5152/5202] Parana (TO) ok
# [5153/5202] Parana (TO) ok
# [5154/5202] Parana (TO) ok
# [5155/5202] Parana (TO) ok
# [5156/5202] Parana (TO) ok
# [5157/5202] Parana (TO) ok
# [5158/5202] Pedro.Afonso (TO) ok
# [5159/5202] Pedro.Afonso (TO) ok
# [5160/5202] Pedro.Afonso (TO) ok
# [5161/5202] Pedro.Afonso (TO) ok
# [5162/5202] Pedro.Afonso (TO) ok
# [5163/5202] Pedro.Afonso (TO) ok
# [5164/5202] Pedro.Afonso (TO) ok
# [5165/5202] Pedro.Afonso (TO) ok
# [5166/5202] Pedro.Afonso (TO) ok
# [5167/5202] Peixe (TO) ok
# [5168/5202] Peixe (TO) ok
# [5169/5202] Peixe (TO) ok
# [5170/5202] Peixe (TO) ok
# [5171/5202] Peixe (TO) ok
# [5172/5202] Peixe (TO) ok
# [5173/5202] Peixe (TO) ok
# [5174/5202] Peixe (TO) ok
# [5175/5202] Peixe (TO) ok
# [5176/5202] Porto.Nacional.AP (TO) ok
# [5177/5202] Porto.Nacional (TO) ok
# [5178/5202] Porto.Nacional.AP (TO) ok
# [5179/5202] Porto.Nacional.AP (TO) ok
# [5180/5202] Porto.Nacional.AP (TO) ok
# [5181/5202] Porto.Nacional.AP (TO) ok
# [5182/5202] Porto.Nacional.AP (TO) ok
# [5183/5202] Porto.Nacional.AP (TO) ok
# [5184/5202] Porto.Nacional.AP (TO) ok
# [5185/5202] Porto.Nacional.AP (TO) ok
# [5186/5202] Porto.Nacional (TO) ok
# [5187/5202] Porto.Nacional (TO) ok
# [5188/5202] Porto.Nacional (TO) ok
# [5189/5202] Porto.Nacional (TO) ok
# [5190/5202] Porto.Nacional (TO) ok
# [5191/5202] Porto.Nacional (TO) ok
# [5192/5202] Porto.Nacional (TO) ok
# [5193/5202] Porto.Nacional (TO) ok
# [5194/5202] Taguatinga (TO) ok
# [5195/5202] Taguatinga (TO) ok
# [5196/5202] Taguatinga (TO) ok
# [5197/5202] Taguatinga (TO) ok
# [5198/5202] Taguatinga (TO) ok
# [5199/5202] Taguatinga (TO) ok
# [5200/5202] Taguatinga (TO) ok
# [5201/5202] Taguatinga (TO) ok
# [5202/5202] Taguatinga (TO) ok
# Salvos 40/624 arquivos de combinação.
# Salvos 80/624 arquivos de combinação.
# Salvos 120/624 arquivos de combinação.
# Salvos 160/624 arquivos de combinação.
# Salvos 200/624 arquivos de combinação.
# Salvos 240/624 arquivos de combinação.
# Salvos 280/624 arquivos de combinação.
# Salvos 320/624 arquivos de combinação.
# Salvos 360/624 arquivos de combinação.
# Salvos 400/624 arquivos de combinação.
# Salvos 440/624 arquivos de combinação.
# Salvos 480/624 arquivos de combinação.
# Salvos 520/624 arquivos de combinação.
# Salvos 560/624 arquivos de combinação.
# Salvos 600/624 arquivos de combinação.
# Salvos 624/624 arquivos de combinação.
# Fim: 20250809_120948
# Arquivos salvos em: Output
